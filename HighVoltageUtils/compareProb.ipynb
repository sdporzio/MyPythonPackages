# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import array
import sys
sys.path.insert(0, '/Users/sdporzio/HighVoltageTask')
import HvPackages.probability as prob

# %%
nMonths = 3
tWindow = 30
nHV = 100
nPMT = 100

x = array.array("f",[])
y1 = array.array("f",[])
y2 = array.array("f",[])
y3 = array.array("f",[])

i = 0
for var in np.arange(0.1,5,0.1):
    nMonths = var
    x.append(var)
    y1.append(prob.prob1(nMonths,tWindow,nHV,nPMT))
    y2.append(prob.prob2(nMonths,tWindow,nHV,nPMT))
    y3.append(prob.prob3(nMonths,tWindow,nHV,nPMT,1))
    i+=1
    
plt.figure(figsize=(15,5), dpi=80)
plt.plot(x, y1, color="red", linewidth=3, linestyle="-", label="p1")
plt.plot(x, y2, color="blue", linewidth=3, linestyle=":", label="p2")
plt.plot(x, y3, color="green", linewidth=3, linestyle="--", label="p3")
plt.legend(loc='lower right', frameon=True)
plt.title('Number of Months vs. Probability')
plt.xlabel('# Months')
plt.ylabel('Probability')
plt.show()

# %%
nMonths = 3
tWindow = 30
nHV = 100
nPMT = 100

x = array.array("f",[])
y1 = array.array("f",[])
y2 = array.array("f",[])
y3 = array.array("f",[])

i = 0
for var in np.arange(1,60,1):
    tWindow = var
    x.append(var)
    y1.append(prob.prob1(nMonths,tWindow,nHV,nPMT))
    y2.append(prob.prob2(nMonths,tWindow,nHV,nPMT))
    y3.append(prob.prob3(nMonths,tWindow,nHV,nPMT,1))
    i+=1

plt.figure(figsize=(15,5), dpi=80)
plt.plot(x, y1, color="red", linewidth=3, linestyle="-", label="p1")
plt.plot(x, y2, color="blue", linewidth=3, linestyle=":", label="p2")
plt.plot(x, y3, color="green", linewidth=3, linestyle="--", label="p3")
plt.legend(loc='lower right', frameon=True)
plt.title('Time Window vs. Probability')
plt.xlabel('Seconds')
plt.ylabel('Probability')
plt.show()

# %%
nMonths = 3
tWindow = 30
nHV = 100
nPMT = 100

x = array.array("f",[])
y1 = array.array("f",[])
y2 = array.array("f",[])
y3 = array.array("f",[])

i = 0
for var in np.arange(1,300,1):
    nHV = var
    x.append(var)
    y1.append(prob.prob1(nMonths,tWindow,nHV,nPMT))
    y2.append(prob.prob2(nMonths,tWindow,nHV,nPMT))
    y3.append(prob.prob3(nMonths,tWindow,nHV,nPMT,1))
    i+=1

plt.figure(figsize=(15,5), dpi=80)
plt.plot(x, y1, color="red", linewidth=3, linestyle="-", label="p1")
plt.plot(x, y2, color="blue", linewidth=3, linestyle=":", label="p2")
plt.plot(x, y3, color="green", linewidth=3, linestyle="--", label="p3")
plt.legend(loc='lower right', frameon=True)
plt.title('Number of HV Events vs. Probability')
plt.xlabel('# HV')
plt.ylabel('Probability')
plt.show()

# %%
nMonths = 3
tWindow = 30
nHV = 100
nPMT = 100

x = array.array("f",[])
y1 = array.array("f",[])
y2 = array.array("f",[])
y3 = array.array("f",[])

i = 0
for var in np.arange(1,300,1):
    nPMT = var
    x.append(var)
    y1.append(prob.prob1(nMonths,tWindow,nHV,nPMT))
    y2.append(prob.prob2(nMonths,tWindow,nHV,nPMT))
    y3.append(prob.prob3(nMonths,tWindow,nHV,nPMT,1))
    i+=1

plt.figure(figsize=(15,5), dpi=80)
plt.plot(x, y1, color="red", linewidth=3, linestyle="-", label="p1")
plt.plot(x, y2, color="blue", linewidth=3, linestyle=":", label="p2")
plt.plot(x, y3, color="green", linewidth=3, linestyle="--", label="p3")
plt.legend(loc='lower right', frameon=True)
plt.title('Number of PMT Events vs. Probability')
plt.xlabel('# PMT')
plt.ylabel('Probability')
plt.show()

# %%
nMonths = 3
tWindow = 30
nHV = 100
nPMT = 100

x = array.array("f",[])
y3 = array.array("f",[])

i = 0
for var in np.arange(0,5,1):
    nCoinc = var
    x.append(var)
    y3.append(prob.prob3(nMonths,tWindow,nHV,nPMT,nCoinc))
    i+=1

plt.figure(figsize=(15,5), dpi=80)
plt.bar(x,y3,1,color="green",alpha=0.75,label='p3',log='True')
plt.legend(loc='lower right', frameon=True)
plt.title('Probability3 vs. Number of Coincidences')
plt.xlabel('# Coincidences')
plt.ylabel('Probability')
plt.show()
